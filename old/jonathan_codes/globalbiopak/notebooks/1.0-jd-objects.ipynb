# %%
import matplotlib.pyplot as plt
from globalbiopak.dataloader import loaddata

# %load_ext autoreload
# %autoreload 2

# %%
d = 100
rand_x = torch.randn(d)
plt.plot(rand_x);

# %%
frequency1 = 2
weight1 = 1
frequency2 = 5
weight2 = 1
grid_x = torch.linspace(0, 2*np.pi, d)
sines_x = torch.sin(weight1 * frequency1 * grid_x) + \
    torch.sin(weight2 * frequency2 * grid_x)
plt.plot(sines_x);

# %%
d = 32
rand_img = torch.randn(d, d)
plt.imshow(rand_img)
plt.colorbar();

# %%
proj = loaddata('cryoEM')
plt.imshow(proj)
plt.colorbar();
# Out:
# /home/jdong/.conda/envs/tomosipo2/lib/python3.8/site-packages/tomosipo/links/torch.py:63: UserWarning: The parameter initial_value should be contiguous. It has been automatically made contiguous. Use `ts.link(x.contiguous())' to inhibit this warning.
#   warnings.warn(

# %%
data = loaddata('MNIST')
plt.imshow(data)
plt.colorbar();

# %%
data = loaddata('cameraman')
plt.imshow(data)
plt.colorbar();

# %%
data = loaddata('cells')
plt.imshow(data)
plt.colorbar();
